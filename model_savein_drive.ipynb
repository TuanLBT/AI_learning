# %% [markdown]
# <a href="https://colab.research.google.com/github/TuanLBT/AI_learning/blob/main/model_savein_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# load mô hình

# %%
from tensorflow import keras
model2 = keras.models.load_model('/content/drive/MyDrive/model.h5')

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 2000)              6146000
#
#  dense_3 (Dense)             (None, 1000)              2001000
#
#  dense_4 (Dense)             (None, 100)               100100
#
# ...
# Total params: 8,247,100
# Trainable params: 8,247,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
#test mo hinh

from keras.utils import load_img
from tensorflow.keras.utils import img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/drive/MyDrive/download.jpg',target_size=(32,32))
plt.imshow(img)

img = img_to_array(img)


img = img.reshape(1,32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model2.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# array([40])

# %%
from matplotlib.image import imread
folder = '/content/drive/MyDrive/img'
for i in range(30):
  plt.subplot(6,5,i+1)
  filename= folder + '/A' + str(i) + '.jpg'
  img = imread(filename)
  plt.imshow(img)
plt.show()
